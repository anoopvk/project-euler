# %%
from collections import defaultdict

# %%
def counter(num):
    a = {"0":"",
    "1": "one",
    "2": "two",
    "3": "three",
    "4": "four",
    "5": "five",
    "6": "six",
    "7": "seven",
    "8": "eight",
    "9": "nine",
    "10": "ten",
    "11": "eleven",
    "12": "twelve",
    "13": "thirteen",
    "14": "fourteen",
    "15": "fifteen",
    "16": "sixteen",
    "17": "seventeen",
    "18": "eighteen",
    "19": "nineteen",
    "20": "twenty",
    "30": "thirty",
    "40": "forty",
    "50": "fifty",
    "60": "sixty",
    "70": "seventy",
    "80": "eighty",
    "90": "ninety",
    }
    


#     a = defaultdict(lambda:"aaaaaa") 
#     print(a["1"])
    if num==1000:
        return len("onethousand")
    elif num>100:
        if counter(num%100)>0:
            return counter(num//100)+len("hundredand")+counter(num%100)
        else:
            return counter(num//100)+len("hundred")
    elif num==100:
        return len("onehundred")
    elif num<100:
        if num>20:
            return len(a[str((num//10)*10)])+len(a[str(num%10)])
        else:
            return len(a[str(num)])

# %%
sum=0
for i in range(1,1001):
    print(i,"  --  ",counter(i))
    sum+=counter(i)
# Out:
# 1   --   3
# 2   --   3
# 3   --   5
# 4   --   4
# 5   --   4
# 6   --   3
# 7   --   5
# 8   --   5
# 9   --   4
# 10   --   3
# 11   --   6
# 12   --   6
# 13   --   8
# 14   --   8
# 15   --   7
# 16   --   7
# 17   --   9
# 18   --   8
# 19   --   8
# 20   --   6
# 21   --   9
# 22   --   9
# 23   --   11
# 24   --   10
# 25   --   10
# 26   --   9
# 27   --   11
# 28   --   11
# 29   --   10
# 30   --   6
# 31   --   9
# 32   --   9
# 33   --   11
# 34   --   10
# 35   --   10
# 36   --   9
# 37   --   11
# 38   --   11
# 39   --   10
# 40   --   5
# 41   --   8
# 42   --   8
# 43   --   10
# 44   --   9
# 45   --   9
# 46   --   8
# 47   --   10
# 48   --   10
# 49   --   9
# 50   --   5
# 51   --   8
# 52   --   8
# 53   --   10
# 54   --   9
# 55   --   9
# 56   --   8
# 57   --   10
# 58   --   10
# 59   --   9
# 60   --   5
# 61   --   8
# 62   --   8
# 63   --   10
# 64   --   9
# 65   --   9
# 66   --   8
# 67   --   10
# 68   --   10
# 69   --   9
# 70   --   7
# ...

# %%
sum
# Out:
# 21124

# %%
print(counter(342))
print(counter(115))
print(counter(501))
# Out:
# 23
# 20
# 17
